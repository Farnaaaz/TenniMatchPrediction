# %% [markdown]
# <a href="https://colab.research.google.com/github/Farnaaaz/TenniMatchPrediction/blob/main/Visualization_for_Priyanshu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import os
import pandas as pd
from io import StringIO
import io
import string
import random
import json
import pickle
import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
from scipy import stats
# from scipy.stats import norm
# from google.colab import drive
import csv
from datetime import datetime

# %% [markdown]
# Filtering and Merging the TOURNAMENT data sets

# %%
tournaments1 = pd.read_csv('match_scores_1991-2016_unindexed_csv.csv')
#tournaments1 = pd.read_csv('ATP data/match_scores_1991-2016_unindexed_csv.csv')

# %%
#Choosing only data for year 2016
filtered_t1 = tournaments1[tournaments1['tourney_year_id'].str.startswith('2016-')]

# %%
filtered_t1.head()
# Out:
#       tourney_year_id  tourney_order tourney_slug  \
# 91415        2016-339              1     brisbane
# 91416        2016-339              1     brisbane
# 91417        2016-339              1     brisbane
# 91418        2016-339              1     brisbane
# 91419        2016-339              1     brisbane
#
#                                  tourney_url_suffix tourney_round_name  \
# 91415  /en/scores/archive/brisbane/339/2016/results             Finals
# 91416  /en/scores/archive/brisbane/339/2016/results        Semi-Finals
# 91417  /en/scores/archive/brisbane/339/2016/results        Semi-Finals
# 91418  /en/scores/archive/brisbane/339/2016/results     Quarter-Finals
# 91419  /en/scores/archive/brisbane/339/2016/results     Quarter-Finals
#
#        round_order  match_order    winner_name winner_player_id  \
# 91415            1            1   Milos Raonic             r975
# 91416            2            1  Roger Federer             f324
# 91417            2            2   Milos Raonic             r975
# 91418            3            1  Roger Federer             f324
# 91419            3            2  Bernard Tomic             ta46
#
#          winner_slug  ... loser_seed match_score_tiebreaks winner_sets_won  \
# 91415   milos-raonic  ...          1                 64 64               2
# 91416  roger-federer  ...          8                 61 64               2
# 91417   milos-raonic  ...          7           76(5) 76(5)               2
# 91418  roger-federer  ...        NaN           64 67(4) 64               2
# 91419  bernard-tomic  ...          2              63 16 63               2
#
#       loser_sets_won winner_games_won loser_games_won  winner_tiebreaks_won  \
# 91415              0               12               8                     0
# 91416              0               12               5                     0
# 91417              0               14              12                     2
# 91418              1               18              15                     0
# 91419              1               13              12                     0
#
#        loser_tiebreaks_won            match_id  \
# 91415                    0  2016-339-r975-f324
# 91416                    0  2016-339-f324-tb69
# 91417                    0  2016-339-r975-ta46
# 91418                    1  2016-339-f324-d875
# 91419                    0  2016-339-ta46-n552
#
#                       match_stats_url_suffix
# 91415  /en/scores/2016/339/MS001/match-stats
# 91416  /en/scores/2016/339/MS002/match-stats
# 91417  /en/scores/2016/339/MS003/match-stats
# 91418  /en/scores/2016/339/MS004/match-stats
# 91419  /en/scores/2016/339/MS007/match-stats
#
# [5 rows x 24 columns]

# %%
filtered_t1_rows = filtered_t1.shape[0]

# %%
print(f"The filtered ATP1 DataFrame has {filtered_t1_rows} rows.")
# Out:
# The filtered ATP1 DataFrame has 3944 rows.

# %%
tournaments2 = pd.read_csv('match_scores_2017_unindexed_csv.csv')
#tournaments2 = pd.read_csv('ATP data/match_scores_2017_unindexed_csv.csv')

# %%
t2_rows = tournaments2.shape[0]
print(f"The filtered ATP2 DataFrame has {t2_rows} rows.")
# Out:
# The filtered ATP2 DataFrame has 3830 rows.

# %%
#Joining two tables vertically
merged_tournaments = pd.concat([filtered_t1, tournaments2], ignore_index=True)
merged_tournaments.head()
# Out:
#   tourney_year_id  tourney_order tourney_slug  \
# 0        2016-339              1     brisbane
# 1        2016-339              1     brisbane
# 2        2016-339              1     brisbane
# 3        2016-339              1     brisbane
# 4        2016-339              1     brisbane
#
#                              tourney_url_suffix tourney_round_name  \
# 0  /en/scores/archive/brisbane/339/2016/results             Finals
# 1  /en/scores/archive/brisbane/339/2016/results        Semi-Finals
# 2  /en/scores/archive/brisbane/339/2016/results        Semi-Finals
# 3  /en/scores/archive/brisbane/339/2016/results     Quarter-Finals
# 4  /en/scores/archive/brisbane/339/2016/results     Quarter-Finals
#
#    round_order  match_order    winner_name winner_player_id    winner_slug  \
# 0            1            1   Milos Raonic             r975   milos-raonic
# 1            2            1  Roger Federer             f324  roger-federer
# 2            2            2   Milos Raonic             r975   milos-raonic
# 3            3            1  Roger Federer             f324  roger-federer
# 4            3            2  Bernard Tomic             ta46  bernard-tomic
#
#    ... loser_seed match_score_tiebreaks winner_sets_won loser_sets_won  \
# 0  ...          1                 64 64               2              0
# 1  ...          8                 61 64               2              0
# 2  ...          7           76(5) 76(5)               2              0
# 3  ...        NaN           64 67(4) 64               2              1
# 4  ...          2              63 16 63               2              1
#
#   winner_games_won loser_games_won  winner_tiebreaks_won  loser_tiebreaks_won  \
# 0               12               8                     0                    0
# 1               12               5                     0                    0
# 2               14              12                     2                    0
# 3               18              15                     0                    1
# 4               13              12                     0                    0
#
#              match_id                 match_stats_url_suffix
# 0  2016-339-r975-f324  /en/scores/2016/339/MS001/match-stats
# 1  2016-339-f324-tb69  /en/scores/2016/339/MS002/match-stats
# 2  2016-339-r975-ta46  /en/scores/2016/339/MS003/match-stats
# 3  2016-339-f324-d875  /en/scores/2016/339/MS004/match-stats
# 4  2016-339-ta46-n552  /en/scores/2016/339/MS007/match-stats
#
# [5 rows x 24 columns]

# %%
#verifying the merge, should be 3830 + 3944
tournament_rows = merged_tournaments.shape[0]
print(f"The filtered merged_ATP DataFrame has {tournament_rows} rows.")
# Out:
# The filtered merged_ATP DataFrame has 7774 rows.

# %% [markdown]
# Filtering and Merging the MATCH data sets

# %%
matches1 = pd.read_csv('match_stats_2017_unindexed_csv.csv') #match_stats_2017_unindexed_csv
matches2 = pd.read_csv('match_stats_1991-2016_unindexed_csv.csv')
# matches1 = pd.read_csv('ATP data/match_stats_2017_unindexed_csv.csv') #match_stats_2017_unindexed_csv
# matches2 = pd.read_csv('ATP data/match_stats_1991-2016_unindexed_csv.csv')

# %%
#Choosing only data for year 2016
filtered_match2 = matches2[matches2['match_id'].str.startswith('2016-')]
filtered_match2.head()
# Out:
#        tourney_order            match_id  \
# 88033              0  2016-339-f324-tb69
# 88034              0  2016-339-r975-f324
# 88035              0  2016-339-f324-d875
# 88036              0  2016-339-r975-ta46
# 88037              0  2016-339-ta46-n552
#
#                       match_stats_url_suffix match_time  match_duration  \
# 88033  /en/scores/2016/339/MS002/match-stats   01:01:00            61.0
# 88034  /en/scores/2016/339/MS001/match-stats   01:27:00            87.0
# 88035  /en/scores/2016/339/MS004/match-stats   02:08:00           128.0
# 88036  /en/scores/2016/339/MS003/match-stats   01:48:00           108.0
# 88037  /en/scores/2016/339/MS007/match-stats   02:00:00           120.0
#
#        winner_aces  winner_double_faults  winner_first_serves_in  \
# 88033          6.0                   0.0                    27.0
# 88034          6.0                   6.0                    34.0
# 88035          7.0                   1.0                    52.0
# 88036         13.0                   3.0                    49.0
# 88037         14.0                   1.0                    62.0
#
#        winner_first_serves_total  winner_first_serve_points_won  ...  \
# 88033                       49.0                           23.0  ...
# 88034                       60.0                           28.0  ...
# 88035                       83.0                           45.0  ...
# 88036                       79.0                           40.0  ...
# 88037                       97.0                           45.0  ...
#
#        loser_second_serve_return_won  loser_second_serve_return_total  \
# 88033                           10.0                             22.0
# 88034                           12.0                             26.0
# 88035                           12.0                             31.0
# 88036                           11.0                             30.0
# 88037                           22.0                             35.0
#
#        loser_break_points_converted  loser_break_points_return_total  \
# 88033                           1.0                              1.0
# 88034                           0.0                              1.0
# 88035                           1.0                              1.0
# 88036                           0.0                              4.0
# 88037                           3.0                             11.0
#
#        loser_service_games_played  loser_return_games_played  \
# 88033                         8.0                        9.0
# 88034                        10.0                       10.0
# 88035                        16.0                       16.0
# 88036                        12.0                       12.0
# 88037                        12.0                       13.0
#
#        loser_return_points_won  loser_return_points_total  \
# 88033                     14.0                       49.0
# 88034                     18.0                       60.0
# 88035                     19.0                       83.0
# 88036                     20.0                       79.0
# 88037                     39.0                       97.0
#
#        loser_total_points_won  loser_total_points_total
# 88033                    41.0                     104.0
# 88034                    57.0                     121.0
# 88035                    86.0                     187.0
# 88036                    77.0                     163.0
# 88037                    89.0                     181.0
#
# [5 rows x 53 columns]

# %%
#2016 and onwards rankings
# atp_rankings_for_EE = pd.read_csv('rankings_1973-2017.csv')
# focused_atp_rankings_for_EE = atp_rankings_for_EE[atp_rankings_for_EE['week_year']>2015]
# selected_columns = ['week_year','rank_number','player_id']
# focused_atp_rankings_for_EE = focused_atp_rankings_for_EE[selected_columns]
# focused_atp_rankings_for_EE

# %%
match2_rows = filtered_match2.shape[0]
print(f"The filtered merged_ATP DataFrame has {match2_rows} rows.")
# Out:
# The filtered merged_ATP DataFrame has 3923 rows.

# %%
match1_rows = matches1.shape[0]
print(f"The filtered ATP2 DataFrame has {match1_rows} rows.")
# Out:
# The filtered ATP2 DataFrame has 3811 rows.

# %%
#Joining two tables vertically
merged_matches = pd.concat([filtered_match2, matches1], ignore_index=True)

# %%
#verifying the merge, should be 3923 + 3811
matches_rows = merged_matches.shape[0]
print(f"The filtered merged_ATP DataFrame has {matches_rows} rows.")
# Out:
# The filtered merged_ATP DataFrame has 7734 rows.

# %% [markdown]
# Merging Player and Ranking Table
# (only) adding ranking data to player table

# %%
players = pd.read_csv('player_overviews_unindexed_csv.csv')
# players = pd.read_csv('ATP data/player_overviews_unindexed_csv.csv')

# %%
ranking = pd.read_csv('rankings_1973-2017_csv.csv')
#ranking = pd.read_csv('ATP data/rankings_1973-2017_csv.csv')

# Calculate the average ranking for each player
avg_ranking = ranking.groupby('player_id')['rank_number'].mean().reset_index()

# Merge only the 'rank_number' column back to the player_df
player_updated = pd.merge(players, avg_ranking[['player_id', 'rank_number']], on='player_id', how='left')

# Rename the new column to reflect it's the average ranking
player_updated = player_updated.rename(columns={'rank_number': 'avg_ranking'})

# Display the final DataFrame
player_updated.head()
player_updated.columns.values
# Out:
# <ipython-input-19-af6655f9b54e>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   ranking = pd.read_csv('rankings_1973-2017_csv.csv')
# array(['player_id', 'player_slug', 'first_name', 'last_name',
#        'player_url', 'flag_code', 'residence', 'birthplace', 'birthdate',
#        'birth_year', 'birth_month', 'birth_day', 'turned_pro',
#        'weight_lbs', 'weight_kg', 'height_ft', 'height_inches',
#        'height_cm', 'handedness', 'backhand', 'avg_ranking'], dtype=object)

# %% [markdown]
# Merging Tournaments and Matches tables with Players table

# %%
## Merge 'merged_matches' and 'merged_tournaments' on 'tourney_order'
merged_df = pd.merge(merged_matches, merged_tournaments, on='tourney_order', how='inner')

# %%
# Merge 'merged_df' with 'player' on 'winner_player_id' and update column names for winner
merged_df = pd.merge(merged_df, player_updated, left_on='winner_player_id', right_on='player_id', how='left', suffixes=('', '_winner'))
merged_df.columns = [col if col not in player_updated.columns else f"winner_{col}" for col in merged_df.columns]

# Merge 'merged_df' with 'player' on 'loser_player_id' and update column names for loser
merged_df = pd.merge(merged_df, player_updated, left_on='loser_player_id', right_on='player_id', how='left', suffixes=('', '_loser'))
merged_df.columns = [col if col not in player_updated.columns else f"loser_{col}" for col in merged_df.columns]

# %%
# Drop duplicate columns (e.g., 'player_id_x', 'player_id_y')
merged_df = merged_df.loc[:, ~merged_df.columns.duplicated()]

# Display the resulting DataFrame
merged_df.head()
# Out:
#    tourney_order          match_id_x               match_stats_url_suffix_x  \
# 0              1  2016-891-cg80-bh09  /en/scores/2016/891/MS003/match-stats
# 1              1  2016-891-cg80-bh09  /en/scores/2016/891/MS003/match-stats
# 2              1  2016-891-cg80-bh09  /en/scores/2016/891/MS003/match-stats
# 3              1  2016-891-cg80-bh09  /en/scores/2016/891/MS003/match-stats
# 4              1  2016-891-cg80-bh09  /en/scores/2016/891/MS003/match-stats
#
#   match_time  match_duration  winner_aces  winner_double_faults  \
# 0   02:57:00           177.0         17.0                   1.0
# 1   02:57:00           177.0         17.0                   1.0
# 2   02:57:00           177.0         17.0                   1.0
# 3   02:57:00           177.0         17.0                   1.0
# 4   02:57:00           177.0         17.0                   1.0
#
#    winner_first_serves_in  winner_first_serves_total  \
# 0                    92.0                      134.0
# 1                    92.0                      134.0
# 2                    92.0                      134.0
# 3                    92.0                      134.0
# 4                    92.0                      134.0
#
#    winner_first_serve_points_won  ...  loser_birth_day  loser_turned_pro  \
# 0                           66.0  ...              8.0            1998.0
# 1                           66.0  ...              3.0            2011.0
# 2                           66.0  ...             21.0            2008.0
# 3                           66.0  ...             16.0            2008.0
# 4                           66.0  ...             29.0            2007.0
#
#    loser_weight_lbs  loser_weight_kg  loser_height_ft  loser_height_inches  \
# 0             187.0             85.0             6'1"                 73.0
# 1             180.0             82.0             6'1"                 73.0
# 2             201.0             91.0             6'5"                 77.0
# 3             176.0             80.0             6'3"                 75.0
# 4             165.0             75.0            5'10"                 70.0
#
#    loser_height_cm  loser_handedness       loser_backhand  loser_avg_ranking
# 0            185.0      Right-Handed  One-Handed Backhand          53.636274
# 1            185.0      Right-Handed  One-Handed Backhand         314.826471
# 2            196.0      Right-Handed  Two-Handed Backhand         209.870763
# 3            191.0      Right-Handed  One-Handed Backhand         194.002075
# 4            178.0      Right-Handed  Two-Handed Backhand         173.074336
#
# [5 rows x 116 columns]

# %%
merged_df.columns.values
# Out:
# array(['tourney_order', 'match_id_x', 'match_stats_url_suffix_x',
#        'match_time', 'match_duration', 'winner_aces',
#        'winner_double_faults', 'winner_first_serves_in',
#        'winner_first_serves_total', 'winner_first_serve_points_won',
#        'winner_first_serve_points_total',
#        'winner_second_serve_points_won',
#        'winner_second_serve_points_total', 'winner_break_points_saved',
#        'winner_break_points_serve_total', 'winner_service_points_won',
#        'winner_service_points_total', 'winner_first_serve_return_won',
#        'winner_first_serve_return_total',
#        'winner_second_serve_return_won',
#        'winner_second_serve_return_total',
#        'winner_break_points_converted',
#        'winner_break_points_return_total', 'winner_service_games_played',
#        'winner_return_games_played', 'winner_return_points_won',
#        'winner_return_points_total', 'winner_total_points_won',
#        'winner_total_points_total', 'loser_aces', 'loser_double_faults',
#        'loser_first_serves_in', 'loser_first_serves_total',
#        'loser_first_serve_points_won', 'loser_first_serve_points_total',
#        'loser_second_serve_points_won', 'loser_second_serve_points_total',
#        'loser_break_points_saved', 'loser_break_points_serve_total',
#        'loser_service_points_won', 'loser_service_points_total',
#        'loser_first_serve_return_won', 'loser_first_serve_return_total',
#        'loser_second_serve_return_won', 'loser_second_serve_return_total',
#        'loser_break_points_converted', 'loser_break_points_return_total',
#        'loser_service_games_played', 'loser_return_games_played',
#        'loser_return_points_won', 'loser_return_points_total',
#        'loser_total_points_won', 'loser_total_points_total',
#        'tourney_year_id', 'tourney_slug', 'tourney_url_suffix',
#        'tourney_round_name', 'round_order', 'match_order', 'winner_name',
#        'winner_player_id', 'winner_slug', 'loser_name', 'loser_player_id',
#        'loser_slug', 'winner_seed', 'loser_seed', 'match_score_tiebreaks',
#        'winner_sets_won', 'loser_sets_won', 'winner_games_won',
#        'loser_games_won', 'winner_tiebreaks_won', 'loser_tiebreaks_won',
#        'match_id_y', 'match_stats_url_suffix_y', 'winner_player_slug',
#        'winner_first_name', 'winner_last_name', 'winner_player_url',
#        'winner_flag_code', 'winner_residence', 'winner_birthplace',
#        'winner_birthdate', 'winner_birth_year', 'winner_birth_month',
#        'winner_birth_day', 'winner_turned_pro', 'winner_weight_lbs',
#        'winner_weight_kg', 'winner_height_ft', 'winner_height_inches',
#        'winner_height_cm', 'winner_handedness', 'winner_backhand',
#        'winner_avg_ranking', 'loser_player_slug', 'loser_first_name',
#        'loser_last_name', 'loser_player_url', 'loser_flag_code',
#        'loser_residence', 'loser_birthplace', 'loser_birthdate',
#        'loser_birth_year', 'loser_birth_month', 'loser_birth_day',
#        'loser_turned_pro', 'loser_weight_lbs', 'loser_weight_kg',
#        'loser_height_ft', 'loser_height_inches', 'loser_height_cm',
#        'loser_handedness', 'loser_backhand', 'loser_avg_ranking'],
#       dtype=object)

# %% [markdown]
# Filtering features for ATP Dataset

# %%
selected_columns = ['tourney_year_id','tourney_slug','tourney_round_name','winner_name','winner_flag_code', 'winner_player_id', 'loser_name','loser_flag_code', 'loser_player_id','winner_sets_won','loser_sets_won', 'loser_birth_year', 'winner_birth_year', 'loser_weight_kg','loser_height_cm', 'winner_weight_kg',	'winner_height_cm',"loser_handedness", "winner_handedness","loser_avg_ranking","winner_avg_ranking"]
ATP_features = merged_df[selected_columns]
# Display the result
ATP_features.head()
# Out:
#   tourney_year_id tourney_slug tourney_round_name    winner_name  \
# 0        2016-339     brisbane             Finals   Milos Raonic
# 1        2016-339     brisbane        Semi-Finals  Roger Federer
# 2        2016-339     brisbane        Semi-Finals   Milos Raonic
# 3        2016-339     brisbane     Quarter-Finals  Roger Federer
# 4        2016-339     brisbane     Quarter-Finals  Bernard Tomic
#
#   winner_flag_code winner_player_id       loser_name loser_flag_code  \
# 0              CAN             r975    Roger Federer             SUI
# 1              SUI             f324    Dominic Thiem             AUT
# 2              CAN             r975    Bernard Tomic             AUS
# 3              SUI             f324  Grigor Dimitrov             BUL
# 4              AUS             ta46    Kei Nishikori             JPN
#
#   loser_player_id  winner_sets_won  ...  loser_birth_year  winner_birth_year  \
# 0            f324                2  ...            1981.0             1990.0
# 1            tb69                2  ...            1993.0             1981.0
# 2            ta46                2  ...            1992.0             1990.0
# 3            d875                2  ...            1991.0             1981.0
# 4            n552                2  ...            1989.0             1992.0
#
#    loser_weight_kg  loser_height_cm  winner_weight_kg  winner_height_cm  \
# 0             85.0            185.0              98.0             196.0
# 1             82.0            185.0              85.0             185.0
# 2             91.0            196.0              98.0             196.0
# 3             80.0            191.0              85.0             185.0
# 4             75.0            178.0              91.0             196.0
#
#    loser_handedness winner_handedness loser_avg_ranking  winner_avg_ranking
# 0      Right-Handed      Right-Handed         53.636274          319.098646
# 1      Right-Handed      Right-Handed        314.826471           53.636274
# 2      Right-Handed      Right-Handed        209.870763          319.098646
# 3      Right-Handed      Right-Handed        194.002075           53.636274
# 4      Right-Handed      Right-Handed        173.074336          209.870763
#
# [5 rows x 21 columns]

# %% [markdown]
# **Merging Betting dataset**

# %%
file_2017 = '2017.xlsx'
file_2018 = '2018.xlsx'
file_2019 = '2019.xlsx'
# file_2017 = 'betting/2017.xlsx'
# file_2018 = 'betting/2018.xlsx'
# file_2019 = 'betting/2019.xlsx'

# Read Excel files into DataFrames
df_2017 = pd.read_excel(file_2017)
df_2018 = pd.read_excel(file_2018)
df_2019 = pd.read_excel(file_2019)

# %%
# Remove specific columns from 2017 (not common)
columns_to_remove = ['EXW', 'EXL', 'LBW', 'LBL']

# Ensure df_2017 is defined with these columns
df_2017 = df_2017.drop(columns=columns_to_remove, errors='ignore')

col_order = ['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts', 'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets', 'Lsets', 'Comment', 'B365W', 'B365L', 'PSW', 'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL']

# Reorder columns in each DataFrame
df_2017 = df_2017[col_order]
df_2018 = df_2018[col_order]
df_2019 = df_2019[col_order]

# Concatenate the DataFrames vertically
betting_merged = pd.concat([df_2017, df_2018, df_2019], ignore_index=True)

betting_merged.head()
# Out:
#    ATP  Location              Tournament       Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International 2017-01-01  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
#
#        Round  Best of       Winner  ... Lsets    Comment  B365W  B365L   PSW  \
# 0  1st Round        3  Thompson J.  ...   0.0  Completed   1.28   3.50  1.31
# 1  1st Round        3     Mahut N.  ...   1.0  Completed   1.50   2.50  1.58
# 2  1st Round        3    Ferrer D.  ...   0.0  Completed   1.90   1.80  2.10
# 3  1st Round        3    Edmund K.  ...   0.0  Completed   1.36   3.00  1.42
# 4  1st Round        3  Dimitrov G.  ...   0.0  Completed   1.40   2.75  1.41
#
#     PSL  MaxW  MaxL  AvgW  AvgL
# 0  3.73  1.33  3.90  1.29  3.50
# 1  2.52  1.59  2.55  1.54  2.43
# 2  1.81  2.15  1.82  2.01  1.77
# 3  3.09  1.42  3.25  1.37  3.01
# 4  3.13  1.46  3.13  1.41  2.85
#
# [5 rows x 36 columns]

# %% [markdown]
# Merging Kaggle Data

# %%
kaggle1 = pd.read_csv('atp_matches_2019_updated.csv')
kaggle2 = pd.read_csv('atp_matches_2020_updated.csv')
# kaggle1 = pd.read_csv('Kaggle_tennis_atp/atp_matches_2019_updated.csv')
# kaggle2 = pd.read_csv('Kaggle_tennis_atp/atp_matches_2020_updated.csv')

# %%
# Concatenate the DataFrames vertically
kaggle_merged = pd.concat([kaggle1, kaggle2], ignore_index=True)

kaggle_merged.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level tourney_date  \
# 0  2019-M020     Brisbane    Hard         32             A   12/31/2018
# 1  2019-M020     Brisbane    Hard         32             A   12/31/2018
# 2  2019-M020     Brisbane    Hard         32             A   12/31/2018
# 3  2019-M020     Brisbane    Hard         32             A   12/31/2018
# 4  2019-M020     Brisbane    Hard         32             A   12/31/2018
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        300     105453          2.0          NaN  ...    54.0     34.0
# 1        299     106421          4.0          NaN  ...    52.0     36.0
# 2        298     105453          2.0          NaN  ...    27.0     15.0
# 3        297     104542          NaN           PR  ...    60.0     38.0
# 4        296     106421          4.0          NaN  ...    56.0     46.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# 0      20.0    14.0       10.0       15.0          9.0             3590.0
# 1       7.0    10.0       10.0       13.0         16.0             1977.0
# 2       6.0     8.0        1.0        5.0          9.0             3590.0
# 3       9.0    11.0        4.0        6.0        239.0              200.0
# 4      19.0    15.0        2.0        4.0         16.0             1977.0
#
#   loser_rank loser_rank_points
# 0       16.0            1977.0
# 1      239.0             200.0
# 2       40.0            1050.0
# 3       31.0            1298.0
# 4       18.0            1855.0
#
# [5 rows x 49 columns]

# %% [markdown]
# Filtering features for Kaggle Dataset

# %%
selected_columns = ['tourney_id','tourney_name','surface','tourney_date','winner_id','winner_name','winner_hand','winner_ht','winner_ioc','winner_age','loser_id','loser_name','loser_hand','loser_ht','loser_ioc','loser_age','best_of','round','winner_rank','loser_rank']
kaggle_features = kaggle_merged[selected_columns]

# Display the result
kaggle_features.head()
# Out:
#   tourney_id tourney_name surface tourney_date  winner_id         winner_name  \
# 0  2019-M020     Brisbane    Hard   12/31/2018     105453       Kei Nishikori
# 1  2019-M020     Brisbane    Hard   12/31/2018     106421     Daniil Medvedev
# 2  2019-M020     Brisbane    Hard   12/31/2018     105453       Kei Nishikori
# 3  2019-M020     Brisbane    Hard   12/31/2018     104542  Jo-Wilfried Tsonga
# 4  2019-M020     Brisbane    Hard   12/31/2018     106421     Daniil Medvedev
#
#   winner_hand  winner_ht winner_ioc  winner_age  loser_id          loser_name  \
# 0           R      178.0        JPN        29.0    106421     Daniil Medvedev
# 1           R      198.0        RUS        22.8    104542  Jo-Wilfried Tsonga
# 2           R      178.0        JPN        29.0    104871       Jeremy Chardy
# 3           R      188.0        FRA        33.7    200282      Alex De Minaur
# 4           R      198.0        RUS        22.8    105683        Milos Raonic
#
#   loser_hand  loser_ht loser_ioc  loser_age  best_of round  winner_rank  \
# 0          R     198.0       RUS       22.8        3     F          9.0
# 1          R     188.0       FRA       33.7        3    SF         16.0
# 2          R     188.0       FRA       31.8        3    SF          9.0
# 3          R     183.0       AUS       19.8        3    QF        239.0
# 4          R     196.0       CAN       28.0        3    QF         16.0
#
#    loser_rank
# 0        16.0
# 1       239.0
# 2        40.0
# 3        31.0
# 4        18.0

# %% [markdown]
# Filetring features for Betting Dataset

# %%
selected_columns = ['ATP','Location','Tournament','Date','Series','Court','Surface','Round','Best of','Winner','Loser','WRank','LRank']
Betting_features = betting_merged[selected_columns]

# Display the result
Betting_features.head()
# Out:
#    ATP  Location              Tournament       Date  Series    Court Surface  \
# 0    1  Brisbane  Brisbane International 2017-01-01  ATP250  Outdoor    Hard
# 1    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 2    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 3    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
# 4    1  Brisbane  Brisbane International 2017-01-02  ATP250  Outdoor    Hard
#
#        Round  Best of       Winner        Loser  WRank  LRank
# 0  1st Round        3  Thompson J.      Ymer E.   79.0  160.0
# 1  1st Round        3     Mahut N.    Robert S.   39.0   54.0
# 2  1st Round        3    Ferrer D.     Tomic B.   21.0   26.0
# 3  1st Round        3    Edmund K.  Escobedo E.   45.0  141.0
# 4  1st Round        3  Dimitrov G.   Johnson S.   17.0   33.0

# %% [markdown]
# Filtering Date for required tables

# %%
# Open the  file for reading and writing
# For file atp_rankings_20s.csv

with open('atp_rankings_20s.csv', 'r', newline='') as infile, \
     open('atp_rankings_20s_updated.csv', 'w', newline='') as outfile:
# with open('Kaggle_tennis_atp/atp_rankings_20s.csv', 'r', newline='') as infile, \
#      open('Kaggle_tennis_atp/atp_rankings_20s_updated.csv', 'w', newline='') as outfile:

    # Create a csv reader object
    reader = csv.reader(infile)

    # Create a csv writer object
    writer = csv.writer(outfile)

    # Read the header row
    headers = next(reader)

    # Write the headers to the output file
    writer.writerow(headers)

    # Iterate over the remaining rows
    for row in reader:
        # Convert the string in the first column to a datetime object
        date_str = row[0]
        date_obj = datetime.strptime(date_str, '%Y%m%d')

        # Format the datetime object as 'MM/DD/YYYY'
        formatted_date = date_obj.strftime('%m/%d/%Y')

        # Update the first column in the row with the formatted date
        row[0] = formatted_date

        # Write the updated row to the output file
        writer.writerow(row)

# For file atp_rankings_current.csv

# with open('Kaggle_tennis_atp/atp_rankings_current.csv', 'r', newline='') as infile, \
#      open('Kaggle_tennis_atp/atp_rankings_current_updated.csv', 'w', newline='') as outfile:
with open('atp_rankings_current.csv', 'r', newline='') as infile, \
     open('atp_rankings_current_updated.csv', 'w', newline='') as outfile:

    # Create a csv reader object
    reader = csv.reader(infile)

    # Create a csv writer object
    writer = csv.writer(outfile)

    # Read the header row
    headers = next(reader)

    # Write the headers to the output file
    writer.writerow(headers)

    # Iterate over the remaining rows
    for row in reader:
        # Convert the string in the first column to a datetime object
        date_str = row[0]
        date_obj = datetime.strptime(date_str, '%Y%m%d')

        # Format the datetime object as 'MM/DD/YYYY'
        formatted_date = date_obj.strftime('%m/%d/%Y')

        # Update the first column in the row with the formatted date
        row[0] = formatted_date

        # Write the updated row to the output file
        writer.writerow(row)

# %%
def update_date_format(input_file, output_file, date_column_index):
    # Open the input and output files
    with open(input_file, 'r', newline='') as infile, \
         open(output_file, 'w', newline='') as outfile:

        # Create a csv reader object
        reader = csv.reader(infile)

        # Create a csv writer object
        writer = csv.writer(outfile)

        # Read the header row
        headers = next(reader)

        # Write the headers to the output file
        writer.writerow(headers)

        # Iterate over the remaining rows
        for row in reader:
            # Convert the string in the specified date column to a datetime object
            date_str = row[date_column_index]
            date_obj = datetime.strptime(date_str, '%Y%m%d')

            # Format the datetime object as 'MM/DD/YYYY'
            formatted_date = date_obj.strftime('%m/%d/%Y')

            # Update the specified date column in the row with the formatted date
            row[date_column_index] = formatted_date

            # Write the updated row to the output file
            writer.writerow(row)

# Update the date format in 'Kaggle_tennis_atp/atp_matches_2019.csv - 'Kaggle_tennis_atp/atp_matches_2023.csv' files

update_date_format('atp_matches_2019.csv', 'atp_matches_2019_updated.csv', 5)
update_date_format('atp_matches_2020.csv', 'atp_matches_2020_updated.csv', 5)
update_date_format('atp_matches_2021.csv', 'atp_matches_2021_updated.csv', 5)
update_date_format('atp_matches_2022.csv', 'atp_matches_2022_updated.csv', 5)
update_date_format('atp_matches_2023.csv', 'atp_matches_2023_updated.csv', 5)

# Update the date format in 'Kaggle_tennis_atp/atp_matches_futures_2019.csv - 'Kaggle_tennis_atp/atp_matches_futures_2023.csv' files

update_date_format('atp_matches_futures_2019.csv', 'atp_matches_futures_2019_updated.csv', 5)
update_date_format('atp_matches_futures_2020.csv', 'atp_matches_futures_2020_updated.csv', 5)
update_date_format('atp_matches_futures_2021.csv', 'atp_matches_futures_2021_updated.csv', 5)
update_date_format('atp_matches_futures_2022.csv', 'atp_matches_futures_2022_updated.csv', 5)
update_date_format('atp_matches_futures_2023.csv', 'atp_matches_futures_2023_updated.csv', 5)

# Update the date format in 'Kaggle_tennis_atp/atp_matches_qual_chall_2019.csv - 'Kaggle_tennis_atp/atp_matches_qual_chall_2023.csv' files

update_date_format('atp_matches_qual_chall_2019.csv', 'atp_matches_qual_chall_2019_updated.csv', 5)
update_date_format('atp_matches_qual_chall_2020.csv', 'atp_matches_qual_chall_2020_updated.csv', 5)
update_date_format('atp_matches_qual_chall_2021.csv', 'atp_matches_qual_chall_2021_updated.csv', 5)
update_date_format('atp_matches_qual_chall_2022.csv', 'atp_matches_qual_chall_2022_updated.csv', 5)
update_date_format('atp_matches_qual_chall_2023.csv', 'atp_matches_qual_chall_2023_updated.csv', 5)
# # Update the date format in 'Kaggle_tennis_atp/atp_matches_2019.csv - 'Kaggle_tennis_atp/atp_matches_2023.csv' files

# update_date_format('Kaggle_tennis_atp/atp_matches_2019.csv', 'Kaggle_tennis_atp/atp_matches_2019_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_2020.csv', 'Kaggle_tennis_atp/atp_matches_2020_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_2021.csv', 'Kaggle_tennis_atp/atp_matches_2021_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_2022.csv', 'Kaggle_tennis_atp/atp_matches_2022_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_2023.csv', 'Kaggle_tennis_atp/atp_matches_2023_updated.csv', 5)

# # Update the date format in 'Kaggle_tennis_atp/atp_matches_futures_2019.csv - 'Kaggle_tennis_atp/atp_matches_futures_2023.csv' files

# update_date_format('Kaggle_tennis_atp/atp_matches_futures_2019.csv', 'Kaggle_tennis_atp/atp_matches_futures_2019_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_futures_2020.csv', 'Kaggle_tennis_atp/atp_matches_futures_2020_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_futures_2021.csv', 'Kaggle_tennis_atp/atp_matches_futures_2021_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_futures_2022.csv', 'Kaggle_tennis_atp/atp_matches_futures_2022_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_futures_2023.csv', 'Kaggle_tennis_atp/atp_matches_futures_2023_updated.csv', 5)

# # Update the date format in 'Kaggle_tennis_atp/atp_matches_qual_chall_2019.csv - 'Kaggle_tennis_atp/atp_matches_qual_chall_2023.csv' files

# update_date_format('Kaggle_tennis_atp/atp_matches_qual_chall_2019.csv', 'Kaggle_tennis_atp/atp_matches_qual_chall_2019_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_qual_chall_2020.csv', 'Kaggle_tennis_atp/atp_matches_qual_chall_2020_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_qual_chall_2021.csv', 'Kaggle_tennis_atp/atp_matches_qual_chall_2021_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_qual_chall_2022.csv', 'Kaggle_tennis_atp/atp_matches_qual_chall_2022_updated.csv', 5)
# update_date_format('Kaggle_tennis_atp/atp_matches_qual_chall_2023.csv', 'Kaggle_tennis_atp/atp_matches_qual_chall_2023_updated.csv', 5)

# %%
#UNION 3 DATASETS !!!!!!!!!!!!!!!!!!!!!!!!!!!!
bet = Betting_features
kag = kaggle_features
atp = ATP_features

# %%
# Select specific columns
selected_columns = ['Location', 'Date', 'Court', 'Surface', 'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank']
bet_focus = bet[selected_columns]
bet_focus.head()
# Out:
#    Location       Date    Court Surface      Round  Best of       Winner  \
# 0  Brisbane 2017-01-01  Outdoor    Hard  1st Round        3  Thompson J.
# 1  Brisbane 2017-01-02  Outdoor    Hard  1st Round        3     Mahut N.
# 2  Brisbane 2017-01-02  Outdoor    Hard  1st Round        3    Ferrer D.
# 3  Brisbane 2017-01-02  Outdoor    Hard  1st Round        3    Edmund K.
# 4  Brisbane 2017-01-02  Outdoor    Hard  1st Round        3  Dimitrov G.
#
#          Loser  WRank  LRank
# 0      Ymer E.   79.0  160.0
# 1    Robert S.   39.0   54.0
# 2     Tomic B.   21.0   26.0
# 3  Escobedo E.   45.0  141.0
# 4   Johnson S.   17.0   33.0

# %%
# fixing the date format
bet_focus['Date'] = pd.to_datetime(bet_focus['Date'])
bet_focus['Date'] = bet_focus['Date'].dt.strftime('%m/%d/%Y')
bet_focus
# Out:
# <ipython-input-35-75305dac1bf3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bet_focus['Date'] = pd.to_datetime(bet_focus['Date'])
# <ipython-input-35-75305dac1bf3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bet_focus['Date'] = bet_focus['Date'].dt.strftime('%m/%d/%Y')
#       Location        Date    Court Surface        Round  Best of  \
# 0     Brisbane  01/01/2017  Outdoor    Hard    1st Round        3
# 1     Brisbane  01/02/2017  Outdoor    Hard    1st Round        3
# 2     Brisbane  01/02/2017  Outdoor    Hard    1st Round        3
# 3     Brisbane  01/02/2017  Outdoor    Hard    1st Round        3
# 4     Brisbane  01/02/2017  Outdoor    Hard    1st Round        3
# ...        ...         ...      ...     ...          ...      ...
# 7875    London  11/15/2019   Indoor    Hard  Round Robin        3
# 7876    London  11/15/2019   Indoor    Hard  Round Robin        3
# 7877    London  11/16/2019   Indoor    Hard   Semifinals        3
# 7878    London  11/16/2019   Indoor    Hard   Semifinals        3
# 7879    London  11/17/2019   Indoor    Hard    The Final        3
#
#              Winner          Loser  WRank  LRank
# 0       Thompson J.        Ymer E.   79.0  160.0
# 1          Mahut N.      Robert S.   39.0   54.0
# 2         Ferrer D.       Tomic B.   21.0   26.0
# 3         Edmund K.    Escobedo E.   45.0  141.0
# 4       Dimitrov G.     Johnson S.   17.0   33.0
# ...             ...            ...    ...    ...
# 7875      Nadal R.   Tsitsipas S.     1.0    6.0
# 7876     Zverev A.    Medvedev D.     7.0    4.0
# 7877  Tsitsipas S.     Federer R.     6.0    3.0
# 7878      Thiem D.      Zverev A.     5.0    7.0
# 7879  Tsitsipas S.       Thiem D.     6.0    5.0
#
# [7880 rows x 10 columns]

# %%
# Select specific columns
selected_columns = ['tourney_name', 'surface', 'tourney_date',
       'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc',
       'winner_age', 'loser_name', 'loser_hand', 'loser_ht',
       'loser_ioc', 'loser_age', 'best_of', 'round', 'winner_rank',
       'loser_rank']
kag_focus = kag[selected_columns]
kag_focus = kag_focus.rename(columns = {'tourney_name': 'Location',
                                        'surface': 'Surface',
                                        'tourney_date': 'Date',
                                        'winner_name': 'Winner',
                                        'winner_hand': 'W_hand',
                                        'winner_ht': 'W_ht',
                                        'winner_ioc': 'W_nationality',
                                        'winner_age': 'W_age',
                                        'loser_name': 'Loser',
                                        'loser_hand': 'L_hand',
                                        'loser_ht': 'L_ht',
                                        'loser_ioc': 'L_nationality',
                                        'loser_age': 'L_age',
                                        'best_of': 'Best of',
                                        'round': 'Round',
                                        'winner_rank': 'WRank',
                                        'loser_rank': 'LRank'})
kag_focus['Date'] = pd.to_datetime(kag_focus['Date'])
kag_focus['Date'] = kag_focus['Date'].dt.strftime('%m/%d/%Y')
kag_focus.head()
# Out:
#    Location Surface        Date              Winner W_hand   W_ht  \
# 0  Brisbane    Hard  12/31/2018       Kei Nishikori      R  178.0
# 1  Brisbane    Hard  12/31/2018     Daniil Medvedev      R  198.0
# 2  Brisbane    Hard  12/31/2018       Kei Nishikori      R  178.0
# 3  Brisbane    Hard  12/31/2018  Jo-Wilfried Tsonga      R  188.0
# 4  Brisbane    Hard  12/31/2018     Daniil Medvedev      R  198.0
#
#   W_nationality  W_age               Loser L_hand   L_ht L_nationality  L_age  \
# 0           JPN   29.0     Daniil Medvedev      R  198.0           RUS   22.8
# 1           RUS   22.8  Jo-Wilfried Tsonga      R  188.0           FRA   33.7
# 2           JPN   29.0       Jeremy Chardy      R  188.0           FRA   31.8
# 3           FRA   33.7      Alex De Minaur      R  183.0           AUS   19.8
# 4           RUS   22.8        Milos Raonic      R  196.0           CAN   28.0
#
#    Best of Round  WRank  LRank
# 0        3     F    9.0   16.0
# 1        3    SF   16.0  239.0
# 2        3    SF    9.0   40.0
# 3        3    QF  239.0   31.0
# 4        3    QF   16.0   18.0

# %%
kag_focus.style.format({"Date": lambda t: t.strftime("%m/%d/%Y")})
kag_focus.head()
# Out:
#    Location Surface        Date              Winner W_hand   W_ht  \
# 0  Brisbane    Hard  12/31/2018       Kei Nishikori      R  178.0
# 1  Brisbane    Hard  12/31/2018     Daniil Medvedev      R  198.0
# 2  Brisbane    Hard  12/31/2018       Kei Nishikori      R  178.0
# 3  Brisbane    Hard  12/31/2018  Jo-Wilfried Tsonga      R  188.0
# 4  Brisbane    Hard  12/31/2018     Daniil Medvedev      R  198.0
#
#   W_nationality  W_age               Loser L_hand   L_ht L_nationality  L_age  \
# 0           JPN   29.0     Daniil Medvedev      R  198.0           RUS   22.8
# 1           RUS   22.8  Jo-Wilfried Tsonga      R  188.0           FRA   33.7
# 2           JPN   29.0       Jeremy Chardy      R  188.0           FRA   31.8
# 3           FRA   33.7      Alex De Minaur      R  183.0           AUS   19.8
# 4           RUS   22.8        Milos Raonic      R  196.0           CAN   28.0
#
#    Best of Round  WRank  LRank
# 0        3     F    9.0   16.0
# 1        3    SF   16.0  239.0
# 2        3    SF    9.0   40.0
# 3        3    QF  239.0   31.0
# 4        3    QF   16.0   18.0

# %%
# Select specific columns
selected_columns = ["tourney_year_id",'tourney_slug', 'tourney_round_name',
       'winner_name', 'winner_flag_code', 'loser_name',
       'loser_flag_code', 'loser_birth_year', 'winner_birth_year',
       'loser_weight_kg', 'loser_height_cm', 'winner_weight_kg',
       'winner_height_cm', 'loser_handedness', 'winner_handedness',"loser_avg_ranking","winner_avg_ranking" ]
atp_focus = atp[selected_columns]
atp_focus = atp_focus.rename(columns = {'tourney_slug': 'Location',
                                        'surface': 'Surface',
                                        'tourney_year_id': 'Date',
                                        'winner_name': 'Winner',
                                        'winner_handedness': 'W_hand',
                                        'winner_height_cm': 'W_ht',
                                        'winner_weight_kg': 'W_wt',
                                        'winner_flag_code': 'W_nationality',
                                        'winner_birth_year': 'W_age',
                                        'loser_name': 'Loser',
                                        'loser_handedness': 'L_hand',
                                        'loser_height_cm': 'L_ht',
                                        'loser_weight_kg': 'L_wt',
                                        'loser_flag_code': 'L_nationality',
                                        'loser_birth_year': 'L_age',
                                        'best_of': 'Best of',
                                        'tourney_round_name': 'Round',
                                        'winner_avg_ranking': 'WRank',
                                        'loser_avg_ranking': 'LRank'})
atp_focus.head()
# Out:
#        Date  Location           Round         Winner W_nationality  \
# 0  2016-339  brisbane          Finals   Milos Raonic           CAN
# 1  2016-339  brisbane     Semi-Finals  Roger Federer           SUI
# 2  2016-339  brisbane     Semi-Finals   Milos Raonic           CAN
# 3  2016-339  brisbane  Quarter-Finals  Roger Federer           SUI
# 4  2016-339  brisbane  Quarter-Finals  Bernard Tomic           AUS
#
#              Loser L_nationality   L_age   W_age  L_wt   L_ht  W_wt   W_ht  \
# 0    Roger Federer           SUI  1981.0  1990.0  85.0  185.0  98.0  196.0
# 1    Dominic Thiem           AUT  1993.0  1981.0  82.0  185.0  85.0  185.0
# 2    Bernard Tomic           AUS  1992.0  1990.0  91.0  196.0  98.0  196.0
# 3  Grigor Dimitrov           BUL  1991.0  1981.0  80.0  191.0  85.0  185.0
# 4    Kei Nishikori           JPN  1989.0  1992.0  75.0  178.0  91.0  196.0
#
#          L_hand        W_hand       LRank       WRank
# 0  Right-Handed  Right-Handed   53.636274  319.098646
# 1  Right-Handed  Right-Handed  314.826471   53.636274
# 2  Right-Handed  Right-Handed  209.870763  319.098646
# 3  Right-Handed  Right-Handed  194.002075   53.636274
# 4  Right-Handed  Right-Handed  173.074336  209.870763

# %%
# simplifying the date to just the year for ATP since there is no exact date
for i in range(2016,2018):
    atp_focus["Date"] = atp_focus["Date"].str.replace('.*'+str(i)+'.*', str(i), regex=True)
atp_focus.head()
# Out:
#    Date  Location           Round         Winner W_nationality  \
# 0  2016  brisbane          Finals   Milos Raonic           CAN
# 1  2016  brisbane     Semi-Finals  Roger Federer           SUI
# 2  2016  brisbane     Semi-Finals   Milos Raonic           CAN
# 3  2016  brisbane  Quarter-Finals  Roger Federer           SUI
# 4  2016  brisbane  Quarter-Finals  Bernard Tomic           AUS
#
#              Loser L_nationality   L_age   W_age  L_wt   L_ht  W_wt   W_ht  \
# 0    Roger Federer           SUI  1981.0  1990.0  85.0  185.0  98.0  196.0
# 1    Dominic Thiem           AUT  1993.0  1981.0  82.0  185.0  85.0  185.0
# 2    Bernard Tomic           AUS  1992.0  1990.0  91.0  196.0  98.0  196.0
# 3  Grigor Dimitrov           BUL  1991.0  1981.0  80.0  191.0  85.0  185.0
# 4    Kei Nishikori           JPN  1989.0  1992.0  75.0  178.0  91.0  196.0
#
#          L_hand        W_hand       LRank       WRank
# 0  Right-Handed  Right-Handed   53.636274  319.098646
# 1  Right-Handed  Right-Handed  314.826471   53.636274
# 2  Right-Handed  Right-Handed  209.870763  319.098646
# 3  Right-Handed  Right-Handed  194.002075   53.636274
# 4  Right-Handed  Right-Handed  173.074336  209.870763

# %%
atp_focus['Date'] = pd.to_datetime(atp_focus['Date'])
atp_focus['Date'] = atp_focus['Date'].dt.strftime('%m/%d/%Y')
atp_focus.head()
# Out:
#          Date  Location           Round         Winner W_nationality  \
# 0  01/01/2016  brisbane          Finals   Milos Raonic           CAN
# 1  01/01/2016  brisbane     Semi-Finals  Roger Federer           SUI
# 2  01/01/2016  brisbane     Semi-Finals   Milos Raonic           CAN
# 3  01/01/2016  brisbane  Quarter-Finals  Roger Federer           SUI
# 4  01/01/2016  brisbane  Quarter-Finals  Bernard Tomic           AUS
#
#              Loser L_nationality   L_age   W_age  L_wt   L_ht  W_wt   W_ht  \
# 0    Roger Federer           SUI  1981.0  1990.0  85.0  185.0  98.0  196.0
# 1    Dominic Thiem           AUT  1993.0  1981.0  82.0  185.0  85.0  185.0
# 2    Bernard Tomic           AUS  1992.0  1990.0  91.0  196.0  98.0  196.0
# 3  Grigor Dimitrov           BUL  1991.0  1981.0  80.0  191.0  85.0  185.0
# 4    Kei Nishikori           JPN  1989.0  1992.0  75.0  178.0  91.0  196.0
#
#          L_hand        W_hand       LRank       WRank
# 0  Right-Handed  Right-Handed   53.636274  319.098646
# 1  Right-Handed  Right-Handed  314.826471   53.636274
# 2  Right-Handed  Right-Handed  209.870763  319.098646
# 3  Right-Handed  Right-Handed  194.002075   53.636274
# 4  Right-Handed  Right-Handed  173.074336  209.870763

# %%
frames = [bet_focus, kag_focus, atp_focus]

result = pd.concat(frames)
result.shape[0]
result.to_csv("cleaned_and_compiled_data_WITH_NULL_VALUES.csv")

# %%
df=pd.read_csv("cleaned_and_compiled_data_WITH_NULL_VALUES.csv")
# Out:
# <ipython-input-42-b9092a3a3bb3>:1: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("cleaned_and_compiled_data_WITH_NULL_VALUES.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  Location        Date    Court Surface      Round  Best of  \
# 0           0  Brisbane  01/01/2017  Outdoor    Hard  1st Round      3.0
# 1           1  Brisbane  01/02/2017  Outdoor    Hard  1st Round      3.0
# 2           2  Brisbane  01/02/2017  Outdoor    Hard  1st Round      3.0
# 3           3  Brisbane  01/02/2017  Outdoor    Hard  1st Round      3.0
# 4           4  Brisbane  01/02/2017  Outdoor    Hard  1st Round      3.0
#
#         Winner        Loser  WRank  ...  W_hand W_ht  W_nationality W_age  \
# 0  Thompson J.      Ymer E.   79.0  ...     NaN  NaN            NaN   NaN
# 1     Mahut N.    Robert S.   39.0  ...     NaN  NaN            NaN   NaN
# 2    Ferrer D.     Tomic B.   21.0  ...     NaN  NaN            NaN   NaN
# 3    Edmund K.  Escobedo E.   45.0  ...     NaN  NaN            NaN   NaN
# 4  Dimitrov G.   Johnson S.   17.0  ...     NaN  NaN            NaN   NaN
#
#    L_hand L_ht  L_nationality L_age  L_wt  W_wt
# 0     NaN  NaN            NaN   NaN   NaN   NaN
# 1     NaN  NaN            NaN   NaN   NaN   NaN
# 2     NaN  NaN            NaN   NaN   NaN   NaN
# 3     NaN  NaN            NaN   NaN   NaN   NaN
# 4     NaN  NaN            NaN   NaN   NaN   NaN
#
# [5 rows x 21 columns]

# %%
null_values = df.isnull().sum()
print("Null Values:")
print(null_values)
# Out:
# Null Values:
# Unnamed: 0            0
# Location              0
# Date                  0
# Court            905050
# Surface          900782
# Round                 0
# Best of          900782
# Winner                0
# Loser                 0
# WRank              3602
# LRank             13395
# W_hand            26751
# W_ht              20221
# W_nationality     11456
# W_age             11457
# L_hand            54347
# L_ht              45572
# L_nationality     19707
# L_age             20191
# L_wt              45816
# W_wt              23169
# dtype: int64

# %%
df['WRank'].fillna(-1, inplace=True)  # Replace with -1 or another value indicating unknown rank
df['LRank'].fillna(-1, inplace=True)  # Replace with -1 or another value indicating unknown rank
df['W_nationality'].fillna('Unknown', inplace=True)  # Replace with 'Unknown' or another category indicating unknown nationality
df['L_nationality'].fillna('Unknown', inplace=True)  # Replace with 'Unknown' or another category indicating unknown nationality

# %%
hand_mapping = {
    'R': 'R',
    'Right-Handed': 'R',
    'L': 'L',
    'Left-Handed': 'L',
    'U': 'U'  # 'U' represents an unknown
}
df['W_hand'] = df['W_hand'].fillna('U')
# Apply the mapping to the 'W_hand' column
df['W_hand'] = df['W_hand'].map(hand_mapping)
unique_values_w_hand = df['W_hand'].unique()
unique_values_w_hand
# Out:
# array(['U', 'R', 'L'], dtype=object)

# %%
hand_mapping = {
    'R': 'R',
    'Right-Handed': 'R',
    'L': 'L',
    'Left-Handed': 'L',
    'U': 'U'  # 'U' represents an unknown
}
df['L_hand'] = df['L_hand'].fillna('U')
# Apply the mapping to the 'W_hand' column
df['L_hand'] = df['L_hand'].map(hand_mapping)
unique_values_l_hand = df['L_hand'].unique()
unique_values_l_hand
# Out:
# array(['U', 'R', 'L'], dtype=object)

# %%
unique_values = df['Round'].unique()
unique_values
# Out:
# array(['1st Round', '2nd Round', 'Quarterfinals', 'Semifinals',
#        'The Final', '3rd Round', '4th Round', 'Round Robin', 'F', 'SF',
#        'QF', 'R16', 'R32', 'R64', 'R128', 'RR', 'Finals', 'Semi-Finals',
#        'Quarter-Finals', 'Round of 16', 'Round of 32',
#        '2nd Round Qualifying', '1st Round Qualifying', 'Round of 64',
#        'Round of 128', '3rd Round Qualifying', 'Olympic Bronze'],
#       dtype=object)

# %%
# Map different representations to a consistent format for the 'Round' column
round_mapping = {
    '1st Round': '1st Round',
    '2nd Round': '2nd Round',
    'Quarterfinals': 'Quarterfinals',
    'Semifinals': 'Semifinals',
    'The Final': 'The Final',
    '3rd Round': '3rd Round',
    '4th Round': '4th Round',
    'Round Robin': 'Round Robin',
    'F': 'The Final',
    'SF': 'Semifinals',
    'QF': 'Quarterfinals',
    'R16': 'Round of 16',
    'R32': 'Round of 32',
    'R64': 'Round of 64',
    'R128': 'Round of 128',
    'RR': 'Round Robin',
    'Finals': 'The Final',
    'Semi-Finals': 'Semifinals',
    'Quarter-Finals': 'Quarterfinals',
    'Round of 16': 'Round of 16',
    'Round of 32': 'Round of 32',
    '2nd Round Qualifying': '2nd Round Qualifying',
    '1st Round Qualifying': '1st Round Qualifying',
    'Round of 64': 'Round of 64',
    'Round of 128': 'Round of 128',
    '3rd Round Qualifying': '3rd Round Qualifying',
    'Olympic Bronze': 'Olympic Bronze'
}

# Apply the mapping to the 'Round' column
df['Round'] = df['Round'].map(round_mapping)

# Verify the changes
unique_values_round = df['Round'].unique()
print("Unique values in 'Round' column after mapping:")
print(unique_values_round)
# Out:
# Unique values in 'Round' column after mapping:
# ['1st Round' '2nd Round' 'Quarterfinals' 'Semifinals' 'The Final'
#  '3rd Round' '4th Round' 'Round Robin' 'Round of 16' 'Round of 32'
#  'Round of 64' 'Round of 128' '2nd Round Qualifying'
#  '1st Round Qualifying' '3rd Round Qualifying' 'Olympic Bronze']

# %%
df['W_age'] = pd.to_numeric(df['W_age'], errors='coerce')
current_year = 2024
df['W_age'] = np.where(df['W_age'] > 100, current_year - df['W_age'], df['W_age'])
median_age = df['W_age'].median()
df['W_age'].fillna(median_age, inplace=True)
unique_values = df['W_age'].unique()
unique_values
# Out:
# array([35. , 29. , 22.8, 33.7, 31.8, 19.8, 28. , 26.4, 27.6, 24.6, 31.6,
#        19.3, 23.6, 29.5, 26.3, 30.7, 33.2, 26.2, 26.8, 28.5, 27.7, 21.1,
#        23.2, 35.5, 28.6, 35.1, 23.5, 32.6, 39.8, 34. , 34.8, 21.6, 29.6,
#        34.9, 30.3, 24.8, 25.4, 20.9, 24.1, 27.4, 23.3, 28.7, 35.2, 29.7,
#        36.7, 31.7, 22.7, 20.5, 29.4, 20.4, 24.7, 21.2, 26.9, 31.2, 21.3,
#        19.4, 27.5, 33.3, 22.9, 27.8, 30.2, 26. , 37.4, 19.9, 25.9, 21.7,
#        25.3, 22.6, 22.1, 28.1, 19.7, 32.3, 32.9, 27. , 26.7, 28.2, 26.6,
#        31.9, 23.7, 29.1, 33. , 31.1, 28.3, 23.8, 31. , 25.8, 33.8, 29.2,
#        33.6, 30.4, 24.9, 32.8, 32.4, 30.8, 31.5, 33.1, 29.8, 36.8, 21.4,
#        31.3, 35.6, 37.1, 23. , 33.4, 30.6, 35.7, 21.9, 20.6, 34.1, 22. ,
#        25. , 18.5, 20.1, 25.6, 25.5, 23.4, 21.8, 33.9, 20. , 32.7, 21. ,
#        26.5, 36.9, 37.5, 22.2, 28.8, 18.9, 32.5, 19.5, 35.3, 40. , 29.3,
#        31.4, 26.1, 22.3, 37.6, 18.6, 30.9, 28.4, 32. , 29.9, 21.5, 34.7,
#        23.9, 20.2, 35.8, 34.2, 25.7, 24.2, 35.4, 23.1, 22.4, 28.9, 27.9,
#        27.1, 37. , 18.7, 24. , 27.2, 19. , 30.5, 17.6, 20.7, 30. , 32.2,
#        37.7, 25.1, 20.3, 17.7, 30.1, 20.8, 34.4, 22.5, 24.3, 25.2, 40.2,
#        37.3, 32.1, 18.8, 34.5, 27.3, 37.8, 24.4, 40.3, 17.9, 33.5, 24.5,
#        34.3, 38. , 37.9, 34.6, 19.1, 38.1, 18.1, 19.6, 40.6, 35.9, 38.2,
#        36. , 18.4, 18. , 16.3, 17.5, 18.2, 36.1, 38.3, 40.8, 38.4, 36.2,
#        16.7, 36.3, 38.9, 36.6, 39.1, 19.2, 39.9, 16.8, 36.5, 17.1, 15.8,
#        16.6, 39. , 43. , 46. , 42. , 41. , 44. , 45. , 48. ])

# %%
df['L_age'] = pd.to_numeric(df['L_age'], errors='coerce')
current_year = 2024
df['L_age'] = np.where(df['L_age'] > 100, current_year - df['L_age'], df['L_age'])
median_age = df['L_age'].median()
df['L_age'].fillna(median_age, inplace=True)
unique_values = df['L_age'].unique()
unique_values
# Out:
# array([35. , 22.8, 33.7, 31.8, 19.8, 28. , 26.4, 27.6, 25.9, 24.6, 31.6,
#        19.3, 23.6, 23.9, 29.5, 26.3, 22.7, 19.4, 26.9, 29.4, 26.6, 28.6,
#        20.5, 23.2, 27.4, 21.1, 33.2, 26.2, 26.8, 28.5, 27.7, 35.5, 35.1,
#        23.5, 28.2, 34.8, 30.9, 22.6, 31.7, 23.7, 30.5, 23.3, 32.9, 37. ,
#        35.2, 25.3, 39.8, 34. , 21.6, 29.6, 34.9, 30.3, 24.8, 25.4, 20.9,
#        24.1, 24.9, 32.3, 29.1, 21.8, 23.1, 24.5, 25.7, 32.7, 18.3, 28.7,
#        29.7, 36.7, 19.7, 29. , 33. , 28.3, 20.4, 24.7, 21.2, 31.2, 21.3,
#        31.1, 31.9, 32.6, 37.4, 21.7, 30.2, 22.1, 24. , 22.9, 28.1, 30.7,
#        27.5, 19.9, 25. , 23. , 18.2, 27. , 33.6, 26.7, 30.6, 26. , 25.6,
#        33.3, 27.8, 34.5, 28.4, 31. , 25.8, 31.3, 25.5, 21.9, 21. , 37.3,
#        35.6, 23.8, 28.9, 36. , 18.9, 37.1, 23.4, 29.3, 29.2, 30.4, 34.1,
#        32.8, 35.3, 20.6, 39.9, 32.4, 30.8, 31.5, 33.8, 17.7, 27.1, 33.1,
#        29.8, 36.8, 18.5, 19.5, 24.2, 33.4, 27.9, 21.4, 35.7, 22.3, 20.8,
#        22. , 22.2, 32. , 26.5, 20.1, 33.9, 20. , 36.9, 17.2, 28.8, 29.9,
#        37.5, 32.5, 40. , 31.4, 26.1, 21.5, 18.6, 34.7, 34.2, 20.2, 17.6,
#        20.7, 35.8, 32.1, 40.1, 35.4, 36.1, 22.4, 30. , 19.6, 25.1, 18.7,
#        27.2, 19. , 34.3, 32.2, 24.3, 37.7, 20.3, 30.1, 25.2, 37.6, 22.5,
#        35.9, 34.4, 40.2, 17.8, 18.8, 27.3, 24.4, 40.3, 37.8, 33.5, 17.9,
#        37.2, 40.4, 34.6, 38. , 37.9, 18. , 16.7, 36.2, 19.1, 38.1, 18.1,
#        40.6, 17.1, 38.2, 19.2, 15.3, 15.2, 18.4, 16.3, 39.6, 38.3, 36.4,
#        40.8, 38.4, 40.9, 36.3, 36.5, 38.7, 38.9, 41.5, 39. , 36.6, 39.1,
#        16.8, 16.1, 43. , 46. , 42. , 41. , 44. , 45. , 48. , 47. ])

# %%
columns_with_missing_values = ['W_ht', 'L_ht', 'L_wt', 'W_wt']

for col in columns_with_missing_values:
    median_value = df[col].median()
    df[col].fillna(median_value, inplace=True)

# %%
df.drop(columns=['Court', 'Surface', 'Best of'], inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Location        Date      Round       Winner        Loser  \
# 0           0  Brisbane  01/01/2017  1st Round  Thompson J.      Ymer E.
# 1           1  Brisbane  01/02/2017  1st Round     Mahut N.    Robert S.
# 2           2  Brisbane  01/02/2017  1st Round    Ferrer D.     Tomic B.
# 3           3  Brisbane  01/02/2017  1st Round    Edmund K.  Escobedo E.
# 4           4  Brisbane  01/02/2017  1st Round  Dimitrov G.   Johnson S.
#
#    WRank  LRank W_hand   W_ht W_nationality  W_age L_hand   L_ht  \
# 0   79.0  160.0      U  185.0       Unknown   35.0      U  185.0
# 1   39.0   54.0      U  185.0       Unknown   35.0      U  185.0
# 2   21.0   26.0      U  185.0       Unknown   35.0      U  185.0
# 3   45.0  141.0      U  185.0       Unknown   35.0      U  185.0
# 4   17.0   33.0      U  185.0       Unknown   35.0      U  185.0
#
#   L_nationality  L_age  L_wt  W_wt
# 0       Unknown   35.0  80.0  80.0
# 1       Unknown   35.0  80.0  80.0
# 2       Unknown   35.0  80.0  80.0
# 3       Unknown   35.0  80.0  80.0
# 4       Unknown   35.0  80.0  80.0

# %%
z_scores = np.abs(stats.zscore(df.select_dtypes(include=[np.number])))
outliers = np.where(z_scores > 30)
df.loc[list(outliers[0])].iloc[0]
# Out:
# Unnamed: 0                     118236
# Location                 buenos-aires
# Date                       01/01/2017
# Round            1st Round Qualifying
# Winner                Guido Andreozzi
# Loser               Manuel Pena Lopez
# WRank                      465.366743
# LRank                      1282.04717
# W_hand                              R
# W_ht                            183.0
# W_nationality                     ARG
# W_age                            33.0
# L_hand                              R
# L_ht                            180.0
# L_nationality                     ARG
# L_age                            26.0
# L_wt                            675.0
# W_wt                             77.0
# Name: 130384, dtype: object

# %%
print("Outliers:")
print((list(zip(outliers[0], outliers[1]))))
# Out:
# Outliers:
# [(130384, 7), (130462, 7), (130540, 7), (130618, 7), (130696, 7), (130774, 7), (130852, 7), (130930, 7), (131008, 7), (131086, 7), (131164, 7), (131242, 7), (131320, 7), (131398, 7), (131476, 7), (131554, 7), (131632, 7), (131710, 7), (131788, 7), (131866, 7), (131944, 7), (132022, 7), (132100, 7), (132178, 7), (132256, 7), (132334, 7), (132412, 7), (132490, 7), (132568, 7), (132646, 7), (132724, 7), (132802, 7), (132880, 7), (132958, 7), (133036, 7), (133114, 7), (133192, 7), (133270, 7), (133348, 7), (133426, 7), (133504, 7), (133582, 7), (133660, 7), (133738, 7), (133816, 7), (133894, 7), (133972, 7), (134050, 7), (134128, 7), (134206, 7), (134284, 7), (134362, 7), (134440, 7), (134518, 7), (134596, 7), (134674, 7), (134752, 7), (134830, 7), (134908, 7), (134986, 7), (135064, 7), (135142, 7), (135220, 7), (135298, 7), (135376, 7), (135454, 7), (135532, 7), (135610, 7), (135688, 7), (135766, 7), (135844, 7), (135922, 7), (136000, 7), (136078, 7), (136156, 7), (136234, 7), (136312, 7), (405501, 7), (405579, 7), (405657, 7), (405735, 7), (405813, 7), (405891, 7), (405969, 7), (406047, 7), (406125, 7), (406203, 7), (406281, 7), (406359, 7), (406437, 7), (406515, 7), (406593, 7), (406671, 7), (406749, 7), (406827, 7), (406905, 7), (406983, 7), (407061, 7), (407139, 7), (407217, 7), (407295, 7), (407373, 7), (407451, 7), (407529, 7), (407607, 7), (407685, 7), (407763, 7), (407841, 7), (407919, 7), (407997, 7), (408075, 7), (408153, 7), (408231, 7), (408309, 7), (408387, 7), (408465, 7), (408543, 7), (408621, 7), (408699, 7), (408777, 7), (408855, 7), (408933, 7), (409011, 7), (409089, 7), (409167, 7), (409245, 7), (409323, 7), (409401, 7), (409479, 7), (409557, 7), (409635, 7), (409713, 7), (409791, 7), (409869, 7), (409947, 7), (410025, 7), (410103, 7), (410181, 7), (410259, 7), (410337, 7), (410415, 7), (410493, 7), (410571, 7), (410649, 7), (410727, 7), (410805, 7), (410883, 7), (410961, 7), (411039, 7), (411117, 7), (411195, 7), (411273, 7), (411351, 7), (411429, 7), (411507, 7), (411585, 7), (411663, 7), (411741, 7), (411819, 7), (411897, 7), (411975, 7), (412053, 7), (412131, 7), (412209, 7), (412287, 7), (412365, 7), (412443, 7), (412521, 7), (412599, 7), (412677, 7), (412755, 7), (412833, 7), (412911, 7), (412989, 7), (413067, 7), (413145, 7), (413223, 7), (413301, 7), (413379, 7), (413457, 7), (413535, 7), (413613, 7), (413691, 7), (413769, 7), (413847, 7), (413925, 7), (414003, 7), (414081, 7), (414159, 7), (414237, 7), (414315, 7), (414393, 7), (414471, 7), (414549, 7), (414627, 7), (414705, 7), (414783, 7), (414861, 7), (414939, 7), (415017, 7), (415095, 7), (415173, 7), (415251, 7), (415329, 7), (415407, 7), (415485, 7), (415563, 7), (415641, 7), (415719, 7), (415797, 7), (415875, 7), (415953, 7), (416031, 7), (416109, 7), (416187, 7), (416265, 7), (416343, 7), (416421, 7), (416499, 7), (416577, 7), (416655, 7), (416733, 7), (416811, 7), (416889, 7), (416967, 7), (417045, 7), (417123, 7), (417201, 7), (417279, 7), (417357, 7), (417435, 7), (417513, 7), (417591, 7), (417669, 7), (417747, 7), (417825, 7), (417903, 7), (417981, 7), (418059, 7), (418137, 7), (418215, 7), (418293, 7), (418371, 7), (418449, 7), (418527, 7), (418605, 7), (418683, 7), (418761, 7), (418839, 7), (418917, 7), (418995, 7), (419073, 7), (419151, 7), (419229, 7), (419307, 7), (419385, 7), (419463, 7), (419541, 7), (419619, 7), (419697, 7), (419775, 7), (419853, 7), (419931, 7), (420009, 7), (420087, 7), (420165, 7), (420243, 7), (420321, 7), (420399, 7), (420477, 7), (420555, 7), (420633, 7), (420711, 7), (420789, 7), (420867, 7), (420945, 7), (421023, 7), (421101, 7), (421179, 7), (421257, 7), (421335, 7), (421413, 7), (421491, 7), (421569, 7), (421647, 7), (421725, 7), (421803, 7), (421881, 7), (421959, 7), (422037, 7), (422115, 7), (422193, 7), (422271, 7), (422349, 7), (422427, 7), (422505, 7), (422583, 7), (422661, 7), (422739, 7), (422817, 7), (422895, 7), (422973, 7), (423051, 7), (423129, 7), (423207, 7), (423285, 7), (423363, 7), (423441, ...

# %%
print(outliers)
# Out:
# (array([130384, 130462, 130540, 130618, 130696, 130774, 130852, 130930,
#        131008, 131086, 131164, 131242, 131320, 131398, 131476, 131554,
#        131632, 131710, 131788, 131866, 131944, 132022, 132100, 132178,
#        132256, 132334, 132412, 132490, 132568, 132646, 132724, 132802,
#        132880, 132958, 133036, 133114, 133192, 133270, 133348, 133426,
#        133504, 133582, 133660, 133738, 133816, 133894, 133972, 134050,
#        134128, 134206, 134284, 134362, 134440, 134518, 134596, 134674,
#        134752, 134830, 134908, 134986, 135064, 135142, 135220, 135298,
#        135376, 135454, 135532, 135610, 135688, 135766, 135844, 135922,
#        136000, 136078, 136156, 136234, 136312, 405501, 405579, 405657,
#        405735, 405813, 405891, 405969, 406047, 406125, 406203, 406281,
#        406359, 406437, 406515, 406593, 406671, 406749, 406827, 406905,
#        406983, 407061, 407139, 407217, 407295, 407373, 407451, 407529,
#        407607, 407685, 407763, 407841, 407919, 407997, 408075, 408153,
#        408231, 408309, 408387, 408465, 408543, 408621, 408699, 408777,
#        408855, 408933, 409011, 409089, 409167, 409245, 409323, 409401,
#        409479, 409557, 409635, 409713, 409791, 409869, 409947, 410025,
#        410103, 410181, 410259, 410337, 410415, 410493, 410571, 410649,
#        410727, 410805, 410883, 410961, 411039, 411117, 411195, 411273,
#        411351, 411429, 411507, 411585, 411663, 411741, 411819, 411897,
#        411975, 412053, 412131, 412209, 412287, 412365, 412443, 412521,
#        412599, 412677, 412755, 412833, 412911, 412989, 413067, 413145,
#        413223, 413301, 413379, 413457, 413535, 413613, 413691, 413769,
#        413847, 413925, 414003, 414081, 414159, 414237, 414315, 414393,
#        414471, 414549, 414627, 414705, 414783, 414861, 414939, 415017,
#        415095, 415173, 415251, 415329, 415407, 415485, 415563, 415641,
#        415719, 415797, 415875, 415953, 416031, 416109, 416187, 416265,
#        416343, 416421, 416499, 416577, 416655, 416733, 416811, 416889,
#        416967, 417045, 417123, 417201, 417279, 417357, 417435, 417513,
#        417591, 417669, 417747, 417825, 417903, 417981, 418059, 418137,
#        418215, 418293, 418371, 418449, 418527, 418605, 418683, 418761,
#        418839, 418917, 418995, 419073, 419151, 419229, 419307, 419385,
#        419463, 419541, 419619, 419697, 419775, 419853, 419931, 420009,
#        420087, 420165, 420243, 420321, 420399, 420477, 420555, 420633,
#        420711, 420789, 420867, 420945, 421023, 421101, 421179, 421257,
#        421335, 421413, 421491, 421569, 421647, 421725, 421803, 421881,
#        421959, 422037, 422115, 422193, 422271, 422349, 422427, 422505,
#        422583, 422661, 422739, 422817, 422895, 422973, 423051, 423129,
#        423207, 423285, 423363, 423441, 423519, 423597, 423675, 423753,
#        423831, 423909, 423987, 424065, 424143, 424221, 424299, 424377,
#        424455, 424533, 424611, 424689, 424767, 424845, 424923, 425001,
#        425079, 425157, 425235, 425313, 425391, 425469, 425547, 425625,
#        425703, 425781, 425859, 425937, 426015, 426093, 426171, 426249,
#        426327, 426405, 426483, 426561, 426639, 426717, 426795, 426873,
#        426951, 427029]), array([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#        7, 7]))

# %%
outlier1 = df.loc[outliers[0]].iloc[0]
print(outlier1)
# Out:
# Unnamed: 0                     118236
# Location                 buenos-aires
# Date                       01/01/2017
# Round            1st Round Qualifying
# Winner                Guido Andreozzi
# Loser               Manuel Pena Lopez
# WRank                      465.366743
# LRank                      1282.04717
# W_hand                              R
# W_ht                            183.0
# W_nationality                     ARG
# W_age                            33.0
# L_hand                              R
# L_ht                            180.0
# L_nationality                     ARG
# L_age                            26.0
# L_wt                            675.0
# W_wt                             77.0
# Name: 130384, dtype: object

# %%
df=df.drop(outliers[0][0])

# %%
duplicate_rows = df[df.duplicated()]

# Display duplicate rows, if any
if len(duplicate_rows) > 0:
    print("Duplicate rows found:")
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %% [markdown]
# dashboard with interactive visualizations

# %%
pip install dash dash-core-components dash-html-components plotly
# Out:
# Collecting dash
#   Downloading dash-2.16.1-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 42.2 MB/s eta 0:00:00
# Collecting dash-core-components
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-html-components
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash) (3.0.2)
# Collecting dash-table==5.0.0 (from dash)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash) (7.1.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash) (2.31.0)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash) (67.7.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash) (3.18.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash) (2024.2.2)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from retrying->dash) (1.16.0)
# Installing collected packages: dash-table, dash-html-components, dash-core-components, retrying, dash
# Successfully installed dash-2.16.1 dash-core-components-2.0.0 dash-html-components-2.0.0 dash-table-5.0.0 retrying-1.3.4

# %%
import pandas as pd
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
# Out:
# <ipython-input-66-3823d2135431>:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# <ipython-input-66-3823d2135431>:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the dashboard
app.layout = html.Div([
    html.H1("Tennis Match Explorer"),
    html.Label("Select a feature to visualize:"),
    dcc.Dropdown(
        id='feature-dropdown',
        options=[
            {'label': 'Winners Age Distribution', 'value': 'winners_age_distribution'},
            {'label': 'Losers Rank Distribution', 'value': 'losers_rank_distribution'},
            {'label': 'Winners Rank Distribution', 'value': 'winners_rank_distribution'},
            {'label': 'Losers Rank Distribution', 'value': 'losers_rank_distribution'}
            # {'label': 'Match Outcome Distribution', 'value': 'match_outcome_distribution'},
            # {'label': 'Surface Preference', 'value': 'surface_preference'},
        ],
        value='match_outcome_distribution'
    ),
    dcc.Graph(id='visualizations')
])

# Define callback to update the graph based on selected feature
@app.callback(
    dash.dependencies.Output('visualizations', 'figure'),
    [dash.dependencies.Input('feature-dropdown', 'value')]
    )

def update_graph(selected_feature):
    if selected_feature == 'winners_age_distribution':
        fig = px.histogram(df, x='W_age', nbins=20, title='Winners Age Distribution')
        fig.update_traces(opacity=0.75)
    elif selected_feature == 'losers_age_distribution':
        fig = px.histogram(df, x='L_age', nbins=20, title='Losers Age Distribution')
        fig.update_traces(opacity=0.75)
    elif selected_feature == 'winners_rank_distribution':
        fig = px.histogram(df, x='WRank', nbins=50, title='Winners Rank Distribution')
        fig.update_traces(opacity=0.75)
    elif selected_feature == 'losers_rank_distribution':
        fig = px.histogram(df, x='LRank', nbins=50, title='Losers Rank Distribution')
        fig.update_traces(opacity=0.75)
    # Add more elif blocks for additional features
    # elif selected_feature == 'match_outcome_distribution':
    #     outcome_counts = pd.concat([df['Winner'], df['Loser']]).value_counts()
    #     fig = px.pie(names=outcome_counts.index, values=outcome_counts.values, title='Match Outcome Distribution')
    # elif selected_feature == 'surface_preference':
    #     surface_counts = df['Surface'].value_counts()
    #     fig = px.bar(x=surface_counts.index, y=surface_counts.values, labels={'x': 'Surface', 'y': 'Number of Matches'}, title='Surface Preference')

    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)

# %%
# import matplotlib.pyplot as plt
# from sklearn.manifold import TSNE
# from sklearn.preprocessing import StandardScaler

# # Assuming you want to use certain features for visualization
# # You can select the features based on your dataset's columns
# features = df[['WRank', 'LRank', 'W_age', 'L_age', 'W_ht', 'L_ht', 'W_wt', 'L_wt']]

# # Standardize the features
# scaler = StandardScaler()
# features_standardized = scaler.fit_transform(features)

# # Reduce dimensionality using t-SNE
# tsne = TSNE(n_components=2, random_state=42)
# tsne_results = tsne.fit_transform(features_standardized)

# # Create a scatter plot of the t-SNE results
# plt.figure(figsize=(10, 6))
# plt.scatter(tsne_results[:, 0], tsne_results[:, 1], alpha=0.5)
# plt.title('t-SNE Visualization of Tennis Matches')
# plt.xlabel('t-SNE Component 1')
# plt.ylabel('t-SNE Component 2')
# plt.show()
